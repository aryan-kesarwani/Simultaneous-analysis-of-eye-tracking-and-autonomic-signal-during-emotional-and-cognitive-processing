# %%
from eye_tracking_analysis_complete import get_values_sj
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from eye_tracking_analysis_complete import get_values_sj
#
# ImportError: cannot import name 'get_values_sj' from 'eye_tracking_analysis_complete' (/Users/aryansmac/Documents/PROJECT/TEEP/TEEP'25/LLD_CTRL_MAIN/Pupil-size-and-microsaccade-analysis-main/new_data/python script/eye_tracking_analysis_complete.py)

# %%
from eye_tracking_analysis_complete import get_values_sj

df = get_values_sj('/path/to/subj_folder', dv='Pupil_l', tw=(0, 2000), iv=['face_emotion', 'word_emotion'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from eye_tracking_analysis_complete import get_values_sj
#       3 df = get_values_sj('/path/to/subj_folder', dv='Pupil_l', tw=(0, 2000), iv=['face_emotion', 'word_emotion'])
#       4 print(df)
#
# ImportError: cannot import name 'get_values_sj' from 'eye_tracking_analysis_complete' (/Users/aryansmac/Documents/PROJECT/TEEP/TEEP'25/LLD_CTRL_MAIN/Pupil-size-and-microsaccade-analysis-main/new_data/python script/eye_tracking_analysis_complete.py)
